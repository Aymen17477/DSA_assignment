# %% [markdown]
# <a href="https://colab.research.google.com/github/Aymen17477/DSA_assignment/blob/main/data_visualization_250200424.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib . pyplot as plt
import numpy as np
# Basic configuration
plt . style . use('seaborn-v0_8') # Modern style
plt . rcParams['figure.figsize'] = (10, 6)
plt . rcParams['font.size'] = 12
print ( f" Matplotlib version : {plt.matplotlib.__version__ }")
# Out:
#  Matplotlib version : 3.10.0
